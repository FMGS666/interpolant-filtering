# %%
import torch
import os
import sys

import seaborn as sns
import matplotlib.pyplot as plt

from pathlib import Path
from ridgeplot import ridgeplot

## exposing path 
sys.path.insert(0, "../")

from int_filt.experiments import create_experiment
from int_filt.utils.config import configuration
from int_filt.utils.utils import ensure_reproducibility

# %%
ACTIVATIONS = {
    "relu": torch.nn.ReLU()
}

OPTIMIZERS = {
    "adam": torch.optim.Adam,
    "adam-w": torch.optim.AdamW
}

SCHEDULERS = {
    "none": None
}

DEVICES = {
    "cpu": torch.device("cpu"),
    "cuda": torch.device("cuda")
}

# %% [markdown]
# Cosine non linearity

# %%
## defining configurations
experiment_conf = {
    "experiment": "nlg",
    "non_linearity": "cos",
    "num_dims": 1,
    "b_net_amortized": True,
    "sigma_x": 0.01,
    "sigma_y": 0.01
}
## parsing default arguments
args = configuration(args=[])
## retrieving activations
args.b_net_activation = ACTIVATIONS[args.b_net_activation]
## retrieving device
args.device = DEVICES[args.device]
## creating experiment
args = vars(args)

## setting current configurations
for k, v in experiment_conf.items():
    args[k] = v

## adding mc configuration
args["mc_config"] = {"num_samples": args["num_samples"]}

## prepare for training drift
b_net_num_grad_step = args["b_net_num_grad_steps"]
b_net_optimizer = args["b_net_optimizer"]
b_net_scheduler = args["b_net_scheduler"]
b_net_lr = args["b_net_lr"]

## dump dir 
dump_dir = args["dump_dir"]
path = Path(dump_dir)
path.mkdir(parents=True, exist_ok=True)

## reproducibility
random_seed = args["random_seed"]
ensure_reproducibility(random_seed)


## displaying current arguments
print(args)

## creating experiment
experiment_nlg_cos = create_experiment(args)

## plotting an example sequence
plt.plot(experiment_nlg_cos.ssm.sim["latent_states"][:, 0, 0])
# Out:
# {'interpolant_method': 'pffp_v0', 'num_samples': 100, 'backbone': 'mlp', 'b_net_hidden_dims': [16], 'b_net_activation': ReLU(), 'b_net_activate_final': False, 'b_net_amortized': True, 'experiment': 'nlg', 'sigma_x': 0.01, 'sigma_y': 0.01, 'beta': 1.0, 'num_dims': 1, 'num_sims': 10000, 'num_iters': 50000, 'non_linearity': 'cos', 'step_size': 0.01, 'log_dir': './out/2024-06-11/run_2024-06-11_16-45-02', 'dump_dir': 'exp/2024-06-11/run_2024-06-11_16-45-02', 'b_net_num_grad_steps': 500, 'b_net_optimizer': 'adam', 'b_net_scheduler': 'none', 'b_net_lr': 0.01, 'random_seed': 128, 'device': device(type='cuda'), 'mc_config': {'num_samples': 100}}
# 100%|██████████| 49999/49999 [00:08<00:00, 5589.44it/s]

# %% [markdown]
# training

# %% [raw]
# ## initializing optimizer
# b_net_optimizer = OPTIMIZERS[b_net_optimizer](experiment_nlg_cos.b_net.backbone.parameters(), lr = b_net_lr)
#
# ## constructing optimization config dictionary
# b_net_optim_config = {
#     "num_grad_steps": b_net_num_grad_step,
#     "optimizer": b_net_optimizer,
#     "scheduler": b_net_scheduler
# }
#
# ## training b_net
# experiment_nlg_cos.train(b_net_optim_config)
# ## saving the weights
# torch.save(experiment_nlg_cos.b_net.state_dict(), os.path.join(dump_dir, "b_net_cos.pt"))

# %% [markdown]
# Exponential non linearity

# %%
## defining configurations
experiment_conf = {
    "experiment": "nlg",
    "non_linearity": "exp",
    "num_dims": 1,
    "b_net_amortized": True,
    "sigma_x": 0.01,
    "sigma_y": 0.01
}
## parsing default arguments
args = configuration(args=[])
## retrieving activations
args.b_net_activation = ACTIVATIONS[args.b_net_activation]
## retrieving device
args.device = DEVICES[args.device]
## creating experiment
args = vars(args)

## setting current configurations
for k, v in experiment_conf.items():
    args[k] = v

## adding mc configuration
args["mc_config"] = {"num_samples": args["num_samples"]}

## prepare for training drift
b_net_num_grad_step = args["b_net_num_grad_steps"]
b_net_optimizer = args["b_net_optimizer"]
b_net_scheduler = args["b_net_scheduler"]
b_net_lr = args["b_net_lr"]

## dump dir 
dump_dir = args["dump_dir"]
path = Path(dump_dir)
path.mkdir(parents=True, exist_ok=True)

## reproducibility
random_seed = args["random_seed"]
ensure_reproducibility(random_seed)

## displaying current arguments
print(args)

## creating experiment
experiment_nlg_exp = create_experiment(args)

## plotting an example sequence
plt.plot(experiment_nlg_exp.ssm.sim["latent_states"][:, 0, 0])
# Out:
# {'interpolant_method': 'pffp_v0', 'num_samples': 100, 'backbone': 'mlp', 'b_net_hidden_dims': [16], 'b_net_activation': ReLU(), 'b_net_activate_final': False, 'b_net_amortized': True, 'experiment': 'nlg', 'sigma_x': 0.01, 'sigma_y': 0.01, 'beta': 1.0, 'num_dims': 1, 'num_sims': 10000, 'num_iters': 50000, 'non_linearity': 'exp', 'step_size': 0.01, 'log_dir': './out/2024-06-11/run_2024-06-11_16-45-11', 'dump_dir': 'exp/2024-06-11/run_2024-06-11_16-45-11', 'b_net_num_grad_steps': 500, 'b_net_optimizer': 'adam', 'b_net_scheduler': 'none', 'b_net_lr': 0.01, 'random_seed': 128, 'device': device(type='cuda'), 'mc_config': {'num_samples': 100}}
# 100%|██████████| 49999/49999 [00:08<00:00, 6095.86it/s]

# %% [raw]
# ## initializing optimizer
# b_net_optimizer = OPTIMIZERS[b_net_optimizer](experiment_nlg_exp.b_net.backbone.parameters(), lr = b_net_lr)
#
# ## constructing optimization config dictionary
# b_net_optim_config = {
#     "num_grad_steps": b_net_num_grad_step,
#     "optimizer": b_net_optimizer,
#     "scheduler": b_net_scheduler
# }
#
# ## training b_net
# experiment_nlg_exp.train(b_net_optim_config)
# ## saving the weights
# torch.save(experiment_nlg_exp.b_net.state_dict(), os.path.join(dump_dir, "b_net_exp.pt"))

# %% [markdown]
# Sine non linearity

# %%
## defining configurations
experiment_conf = {
    "experiment": "nlg",
    "non_linearity": "sin",
    "num_dims": 1,
    "b_net_amortized": True,
    "sigma_x": 0.01,
    "sigma_y": 0.01
}
## parsing default arguments
args = configuration(args=[])
## retrieving activations
args.b_net_activation = ACTIVATIONS[args.b_net_activation]
## retrieving device
args.device = DEVICES[args.device]
## creating experiment
args = vars(args)

## setting current configurations
for k, v in experiment_conf.items():
    args[k] = v

## adding mc configuration
args["mc_config"] = {"num_samples": args["num_samples"]}

## prepare for training drift
b_net_num_grad_step = args["b_net_num_grad_steps"]
b_net_optimizer = args["b_net_optimizer"]
b_net_scheduler = args["b_net_scheduler"]
b_net_lr = args["b_net_lr"]

## dump dir 
dump_dir = args["dump_dir"]
path = Path(dump_dir)
path.mkdir(parents=True, exist_ok=True)

## reproducibility
random_seed = args["random_seed"]
ensure_reproducibility(random_seed)

## displaying current arguments
print(args)

## creating experiment
experiment_nlg_sin = create_experiment(args)

## plotting an example sequence
plt.plot(experiment_nlg_sin.ssm.sim["latent_states"][:, 0, 0])
# Out:
# {'interpolant_method': 'pffp_v0', 'num_samples': 100, 'backbone': 'mlp', 'b_net_hidden_dims': [16], 'b_net_activation': ReLU(), 'b_net_activate_final': False, 'b_net_amortized': True, 'experiment': 'nlg', 'sigma_x': 0.01, 'sigma_y': 0.01, 'beta': 1.0, 'num_dims': 1, 'num_sims': 10000, 'num_iters': 50000, 'non_linearity': 'sin', 'step_size': 0.01, 'log_dir': './out/2024-06-11/run_2024-06-11_16-45-20', 'dump_dir': 'exp/2024-06-11/run_2024-06-11_16-45-20', 'b_net_num_grad_steps': 500, 'b_net_optimizer': 'adam', 'b_net_scheduler': 'none', 'b_net_lr': 0.01, 'random_seed': 128, 'device': device(type='cuda'), 'mc_config': {'num_samples': 100}}
# 100%|██████████| 49999/49999 [00:07<00:00, 6996.26it/s]

# %% [raw]
# ## initializing optimizer
# b_net_optimizer = OPTIMIZERS[b_net_optimizer](experiment_nlg_sin.b_net.backbone.parameters(), lr = b_net_lr)
#
# ## constructing optimization config dictionary
# b_net_optim_config = {
#     "num_grad_steps": b_net_num_grad_step,
#     "optimizer": b_net_optimizer,
#     "scheduler": b_net_scheduler
# }
#
# ## training b_net
# experiment_nlg_sin.train(b_net_optim_config)
# ## saving the weights
# torch.save(experiment_nlg_sin.b_net.state_dict(), os.path.join(dump_dir, "b_net_sin.pt"))
